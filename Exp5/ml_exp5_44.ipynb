# %% [markdown]
# # Experiment 5: Disease Prediction using Naive Bayes and Neural Network with Comparison of Classifiers
# ## Name: Sufiyan Mehsanewala
# ## Class: SE AIML
# ## Roll no: 44

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
import pandas as pd

# %%
data = load_breast_cancer()

X = data.data
y = data.target

print("Classes: ", data.target_names)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=44)
# Out:
# Classes:  ['malignant' 'benign']

# %%
# print(data.data.shape)
df = pd.DataFrame(data.data, columns=data.feature_names)
df.shape
# Out:
# (569, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
df.tail()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# ...

# %%
df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# dtype: int64

# %% [markdown]
# ## A: Training and Test Accuracy (Learning Behaviour of ML Model)

# %% [markdown]
# ### Logistic Regression

# %%
lr = LogisticRegression(max_iter = 5000)
lr.fit(X_train, y_train)
pred_lr = lr.predict(X_test)
print("Logistic TestAccuracy:", accuracy_score(y_test, pred_lr))
pred_lr_train = lr.predict(X_train)
print("Logistic TrainAccuracy:", accuracy_score(y_train, pred_lr_train))
# Out:
# Logistic TestAccuracy: 0.9707602339181286
# Logistic TrainAccuracy: 0.9623115577889447

# %% [markdown]
# ### Decision Tree Classifier

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
pred_dt = dt.predict(X_test)
print("Logistic TestAccuracy:", accuracy_score(y_test, pred_dt))
pred_dt_train = dt.predict(X_train)
print("Logistic TrainAccuracy:", accuracy_score(y_train, pred_dt_train))
# Out:
# Logistic TestAccuracy: 0.935672514619883
# Logistic TrainAccuracy: 1.0

# %% [markdown]
# ### KNN

# %%
kn = KNeighborsClassifier()
kn.fit(X_train, y_train)
pred_kn = kn.predict(X_test)
print("Logistic TestAccuracy:", accuracy_score(y_test, pred_kn))
pred_kn_train = kn.predict(X_train)
print("Logistic TrainAccuracy:", accuracy_score(y_train, pred_kn_train))
# Out:
# Logistic TestAccuracy: 0.9590643274853801
# Logistic TrainAccuracy: 0.9346733668341709

# %% [markdown]
# ### Naive Bayes

# %%
nb = GaussianNB()
nb.fit(X_train, y_train)
pred_nb = nb.predict(X_test)
print("Logistic TestAccuracy:", accuracy_score(y_test, pred_nb))
pred_nb_train = nb.predict(X_train)
print("Logistic TrainAccuracy:", accuracy_score(y_train, pred_nb_train))
# Out:
# Logistic TestAccuracy: 0.9415204678362573
# Logistic TrainAccuracy: 0.9371859296482412

# %% [markdown]
# ### Neural Network

# %%
nn = MLPClassifier(max_iter = 2000)
nn.fit(X_train, y_train)
pred_nn = nn.predict(X_test)
print("Logistic TestAccuracy:", accuracy_score(y_test, pred_nn))
pred_nn_train = nn.predict(X_train)
print("Logistic TrainAccuracy:", accuracy_score(y_train, pred_nn_train))
# Out:
# Logistic TestAccuracy: 0.9590643274853801
# Logistic TrainAccuracy: 0.9271356783919598

# %% [markdown]
# ## B: Classification Performance Metrics (Threshold-based Evaluation)

# %% [markdown]
# ### Logistic Regression

# %%
precision_lr = precision_score(y_test, pred_lr)
recall_lr = recall_score(y_test, pred_lr)
f1_lr = f1_score(y_test, pred_lr)
roc_auc_lr = roc_auc_score(y_test, pred_lr)
print("Logistic Regression Metrics:")
print("Precision:", precision_lr)
print("Recall:", recall_lr)
print("F1 Score:", f1_lr)
print("ROC AUC Score:", roc_auc_lr)
# Out:
# Logistic Regression Metrics:
# Precision: 0.963963963963964
# Recall: 0.9907407407407407
# F1 Score: 0.9771689497716894
# ROC AUC Score: 0.9636243386243386

# %% [markdown]
# ### Decision Tree Classifier

# %%
precision_dt = precision_score(y_test, pred_dt)
recall_dt = recall_score(y_test, pred_dt)
f1_dt = f1_score(y_test, pred_dt)
roc_auc_dt = roc_auc_score(y_test, pred_dt)
print("Decision Tree Metrics:")
print("Precision:", precision_lr)
print("Recall:", recall_lr)
print("F1 Score:", f1_lr)
print("ROC AUC Score:", roc_auc_dt)
# Out:
# Decision Tree Metrics:
# Precision: 0.963963963963964
# Recall: 0.9907407407407407
# F1 Score: 0.9771689497716894
# ROC AUC Score: 0.9358465608465608

# %% [markdown]
# ### KNN

# %%
precision_knn = precision_score(y_test, pred_kn)
recall_knn = recall_score(y_test, pred_kn)
f1_knn = f1_score(y_test, pred_kn)
roc_auc_knn = roc_auc_score(y_test, pred_kn)
print("K Nearest Neighbor Metrics:")
print("Precision:", precision_knn)
print("Recall:", recall_knn)
print("F1 Score:", f1_knn)
print("ROC AUC Score:", roc_auc_knn)
# Out:
# K Nearest Neighbor Metrics:
# Precision: 0.9719626168224299
# Recall: 0.9629629629629629
# F1 Score: 0.9674418604651163
# ROC AUC Score: 0.9576719576719575

# %% [markdown]
# ### Naive Bayes

# %%
precision_nb = precision_score(y_test, pred_nb)
recall_nb = recall_score(y_test, pred_nb)
f1_nb = f1_score(y_test, pred_nb)
roc_auc_nb = roc_auc_score(y_test, pred_nb)
print("Naive Bayes Metrics:")
print("Precision:", precision_nb)
print("Recall:", recall_nb)
print("F1 Score:", f1_nb)
print("ROC AUC Score:", roc_auc_nb)
# Out:
# Naive Bayes Metrics:
# Precision: 0.9537037037037037
# Recall: 0.9537037037037037
# F1 Score: 0.9537037037037037
# ROC AUC Score: 0.9371693121693122

# %% [markdown]
# ### Neural Network

# %%
precision_nn = precision_score(y_test, pred_nn)
recall_nn = recall_score(y_test, pred_nn)
f1_nn = f1_score(y_test, pred_nn)
roc_auc_nn = roc_auc_score(y_test, pred_nn)
print("Neural Network Metrics:")
print("Precision:", precision_nn)
print("Recall:", recall_nn)
print("F1 Score:", f1_nn)
print("ROC AUC Score:", roc_auc_nn)
# Out:
# Neural Network Metrics:
# Precision: 0.9809523809523809
# Recall: 0.9537037037037037
# F1 Score: 0.9671361502347418
# ROC AUC Score: 0.9609788359788359

# %% [markdown]
# ### C: Confusion Matrix and Error Analysis

# %% [markdown]
# ### Logistic Regression

# %%
cm_lr = confusion_matrix(y_test, pred_lr)
print("\nDecision Tree Confusion Matrix: ")
print(cm_lr)
TN2, FP2, FN2, TP2 = cm_lr.ravel()
type1_lr = FP2 / (FP2 + TN2)
type2_lr = FN2 / (FN2 + TP2)

print("FP (type-1): ", FP2)
print("FP (type-2): ", FN2)
print("type-1 Error Rate in %: ", type1_lr*100)
print("type-2 Error Rate in %: ", type2_lr*100)
# Out:
# Decision Tree Confusion Matrix:
# [[ 59   4]
#  [  1 107]]
# FP (type-1):  4
# FP (type-2):  1
# type-1 Error Rate in %:  6.349206349206349
# type-2 Error Rate in %:  0.9259259259259258

# %% [markdown]
# ### Decision Tree Classifier

# %%
cm_dt = confusion_matrix(y_test, pred_dt)
print("\nDecision Tree Confusion Matrix: ")
print(cm_dt)
TN2, FP2, FN2, TP2 = cm_dt.ravel()
type1_dt = FP2 / (FP2 + TN2)
type2_dt = FN2 / (FN2 + TP2)

print("FP (type-1): ", FP2)
print("FP (type-2): ", FN2)
print("type-1 Error Rate in %: ", type1_dt*100)
print("type-2 Error Rate in %: ", type2_dt*100)
# Out:
# Decision Tree Confusion Matrix:
# [[ 59   4]
#  [  7 101]]
# FP (type-1):  4
# FP (type-2):  7
# type-1 Error Rate in %:  6.349206349206349
# type-2 Error Rate in %:  6.481481481481481

# %% [markdown]
# ### KNN

# %%
cm_kn = confusion_matrix(y_test, pred_kn)
print("\nDecision Tree Confusion Matrix: ")
print(cm_kn)
TN2, FP2, FN2, TP2 = cm_kn.ravel()
type1_kn = FP2 / (FP2 + TN2)
type2_kn = FN2 / (FN2 + TP2)

print("FP (type-1): ", FP2)
print("FP (type-2): ", FN2)
print("type-1 Error Rate in %: ", type1_kn*100)
print("type-2 Error Rate in %: ", type2_kn*100)
# Out:
# Decision Tree Confusion Matrix:
# [[ 60   3]
#  [  4 104]]
# FP (type-1):  3
# FP (type-2):  4
# type-1 Error Rate in %:  4.761904761904762
# type-2 Error Rate in %:  3.7037037037037033

# %% [markdown]
# ### Naive Bayes

# %%
cm_nb = confusion_matrix(y_test, pred_nb)
print("\nDecision Tree Confusion Matrix: ")
print(cm_nb)
TN2, FP2, FN2, TP2 = cm_nb.ravel()
type1_nb = FP2 / (FP2 + TN2)
type2_nb = FN2 / (FN2 + TP2)

print("FP (type-1): ", FP2)
print("FP (type-2): ", FN2)
print("type-1 Error Rate in %: ", type1_nb*100)
print("type-2 Error Rate in %: ", type2_nb*100)
# Out:
# Decision Tree Confusion Matrix:
# [[ 58   5]
#  [  5 103]]
# FP (type-1):  5
# FP (type-2):  5
# type-1 Error Rate in %:  7.936507936507936
# type-2 Error Rate in %:  4.62962962962963

# %% [markdown]
# ### Neural Network

# %%
cm_nn = confusion_matrix(y_test, pred_nn)
print("\nDecision Tree Confusion Matrix: ")
print(cm_nn)
TN2, FP2, FN2, TP2 = cm_nn.ravel()
type1_nn = FP2 / (FP2 + TN2)
type2_nn = FN2 / (FN2 + TP2)

print("FP (type-1): ", FP2)
print("FP (type-2): ", FN2)
print("type-1 Error Rate in %: ", type1_nn*100)
print("type-2 Error Rate in %: ", type2_nn*100)
# Out:
# Decision Tree Confusion Matrix:
# [[ 61   2]
#  [  5 103]]
# FP (type-1):  2
# FP (type-2):  5
# type-1 Error Rate in %:  3.1746031746031744
# type-2 Error Rate in %:  4.62962962962963
